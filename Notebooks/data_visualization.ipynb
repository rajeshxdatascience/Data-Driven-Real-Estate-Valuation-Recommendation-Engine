# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("/content/data_for_viz2.csv")

# %%
df.drop(columns=['furnishing_type','luxury_score'],inplace=True)

# %%
df.head()
# Out:
#                   society       sector  price  price_per_sqft  bedRoom  \
# 0         godrej meridien  Sector 106    2.85         15364.0        3
# 1     experion windchants  Sector 112    6.25         16609.0        3
# 2              godrej 101   Sector 79    3.50         16471.0        3
# 3  dlf new town heights 1   Sector 90    2.85         10451.0        4
# 4     experion windchants  Sector 112    8.40         17327.0        4
#
#    bathroom balcony floorNum      facing       agePossession  built_up_area  \
# 0         3       3        8        East      Relatively New        1653.00
# 1         5       3        6       North      Moderately Old        2873.18
# 2         3       3       11       North  Under Construction        1603.00
# 3         4      3+        4  North-West      Moderately Old        2725.00
# 4         6      3+        6        West      Moderately Old        3655.35
#
#    study room  servant room  store room  pooja room  others   latitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1528 entries, 0 to 1527
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   society         1528 non-null   object
#  1   sector          1528 non-null   object
#  2   price           1528 non-null   float64
#  3   price_per_sqft  1528 non-null   float64
#  4   bedRoom         1528 non-null   int64
#  5   bathroom        1528 non-null   int64
#  6   balcony         1528 non-null   object
#  7   floorNum        1528 non-null   object
#  8   facing          1528 non-null   object
#  9   agePossession   1528 non-null   object
#  10  built_up_area   1528 non-null   float64
#  11  study room      1528 non-null   int64
#  12  servant room    1528 non-null   int64
#  13  store room      1528 non-null   int64
#  14  pooja room      1528 non-null   int64
#  15  others          1528 non-null   int64
#  16  latitude        1528 non-null   float64
# ...

# %%
group_df = df.groupby('sector').mean(numeric_only=True)[['price','price_per_sqft','built_up_area','latitude','longitude']]

# %%
group_df
# Out:
#                         price  price_per_sqft  built_up_area   latitude  \
# sector
# Block T Sector-109   4.500000    15385.000000    2499.800000  28.515422
# DLF Phase 2          6.650000    25003.000000    2575.000000  28.486005
# DLF Phase 4          6.120000    26338.200000    2294.200000  28.463146
# DLF Phase 5          8.825000    30535.800000    2754.800000  28.450455
# Dwarka Expressway    2.550000    12289.000000    2385.000000  28.454927
# ...                       ...             ...            ...        ...
# Sohna Road           1.350000    11250.000000    1379.000000  28.431703
# South City 1         2.550000    21040.000000    1393.000000  28.462221
# Sushant Lok Phase 3  2.650000    12934.500000    1638.000000  28.419553
# Tikri                3.150000    15591.500000    1972.500000  28.406236
# sector 58            5.020714    23298.142857    1914.928571  28.412979
#
#                      longitude
# sector
# Block T Sector-109   77.004647
# ...

# %%
fig = px.scatter_mapbox(group_df, lat="latitude", lon="longitude", color="price_per_sqft", size='built_up_area',
                  color_continuous_scale=px.colors.cyclical.IceFire, zoom=10,
                  mapbox_style="open-street-map",text=group_df.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1 = pd.read_csv("/content/gurgaon_final.csv")

# %%
df1.head()
# Out:
#                                        property_name  \
# 0  4BHK  4Baths Flat/Apartment for Sale in DLF Th...
# 1  3BHK  3Baths Flat/Apartment for Sale in Godrej...
# 2  3BHK  5Baths Flat/Apartment for Sale in Experi...
# 3  3BHK  3Baths Flat/Apartment for Sale in Godrej...
# 4  4BHK  4Baths Flat/Apartment for Sale in DLF Ne...
#
#                                                 link                 society  \
# 0  https://www.99acres.com/4-bhk-bedroom-apartmen...       DLF The Magnolias
# 1  https://www.99acres.com/3-bhk-bedroom-apartmen...         Godrej Meridien
# 2  https://www.99acres.com/3-bhk-bedroom-apartmen...     Experion Windchants
# 3  https://www.99acres.com/3-bhk-bedroom-apartmen...              Godrej 101
# 4  https://www.99acres.com/4-bhk-bedroom-apartmen...  DLF New Town Heights 1
#
#         price  area                                       areaWithType  \
# 0    45 Crore  6400  Super Built-up area 6400(594.58 sq.m.)Built-up...
# ...

# %%
wordcloud_df = df1.merge(df, left_index=True, right_index=True)[['features','sector']]

# %%
wordcloud_df.head()
# Out:
#                                             features       sector
# 0                               ['Vaastu Compliant']  Sector 106
# 1  ['Vaastu Compliant', 'Recently Renovated', 'Pi...  Sector 112
# 2                                                 []   Sector 79
# 3                                                 []   Sector 90
# 4  ['Centrally Air Conditioned', 'Vaastu Complian...  Sector 112

# %%
wordcloud_df['features'] = wordcloud_df['features'].replace('[]',np.nan)

# %%
wordcloud_df.dtypes
# Out:
# features    object
# sector      object
# dtype: object

# %%
import ast
main = []
for item in wordcloud_df['features'].dropna().apply(ast.literal_eval):
  main.extend(item)

# %%
main
# Out:
# ['Vaastu Compliant',
#  'Vaastu Compliant',
#  'Recently Renovated',
#  'Piped-gas',
#  'Centrally Air Conditioned',
#  'Vaastu Compliant',
#  'Private Garden / Terrace',
#  'High Ceiling Height',
#  'False Ceiling Lighting',
#  'Separate entry for servant room',
#  'Piped-gas',
#  'Recently Renovated',
#  'Power Back-up',
#  'Centrally Air Conditioned',
#  'High Ceiling Height',
#  'Piped-gas',
#  'High Ceiling Height',
#  'Piped-gas',
#  'Centrally Air Conditioned',
#  'Vaastu Compliant',
#  'High Ceiling Height',
#  'False Ceiling Lighting',
#  'Separate entry for servant room',
#  'Piped-gas',
#  'Recently Renovated',
#  'Power Back-up',
#  'High Ceiling Height',
#  'False Ceiling Lighting',
#  'Separate entry for servant room',
#  'Vaastu Compliant',
#  'High Ceiling Height',
#  'Separate entry for servant room',
#  'Piped-gas',
#  'Vaastu Compliant',
#  'Centrally Air Conditioned',
#  'High Ceiling Height',
#  'False Ceiling Lighting',
#  'Recently Renovated',
#  'Piped-gas',
# ...

# %%
from wordcloud import WordCloud

# %%
feature_text = ' '.join(main)

# %%
feature_text
# Out:
# 'Vaastu Compliant Vaastu Compliant Recently Renovated Piped-gas Centrally Air Conditioned Vaastu Compliant Private Garden / Terrace High Ceiling Height False Ceiling Lighting Separate entry for servant room Piped-gas Recently Renovated Power Back-up Centrally Air Conditioned High Ceiling Height Piped-gas High Ceiling Height Piped-gas Centrally Air Conditioned Vaastu Compliant High Ceiling Height False Ceiling Lighting Separate entry for servant room Piped-gas Recently Renovated Power Back-up High Ceiling Height False Ceiling Lighting Separate entry for servant room Vaastu Compliant High Ceiling Height Separate entry for servant room Piped-gas Vaastu Compliant Centrally Air Conditioned High Ceiling Height False Ceiling Lighting Recently Renovated Piped-gas Centrally Air Conditioned Vaastu Compliant Private Garden / Terrace High Ceiling Height Separate entry for servant room Piped-gas Recently Renovated Power Back-up Vaastu Compliant Centrally Air Conditioned High Ceiling Height False 
# ...

# %%
plt.rcParams["font.family"] = "Arial"

wordcloud = WordCloud(width = 800, height = 800,
                      background_color ='white',
                      stopwords = set(['s']),  # Any stopwords you'd like to exclude
                      min_font_size = 10).generate(feature_text)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show() # st.pyplot()

# %%
fig = px.scatter(df, x="built_up_area", y="price", color="bedRoom", title="Area Vs Price")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df, names='bedRoom', title='Total Bill Amount by Day')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp_df = df[df['bedRoom'] <= 4]
# Create side-by-side boxplots of the total bill amounts by day
fig = px.box(temp_df, x='bedRoom', y='price', title='BHK Price Range')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
